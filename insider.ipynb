# %%
import requests
import json

url = "https://api3.oslo.oslobors.no/v1/newsreader/list?category=1102&fromDate=2025-09-01"

headers = {
    "accept": "*/*",
    "accept-language": "en,en-GB;q=0.9,nb;q=0.8,en-US;q=0.7,fr-FR;q=0.6,fr;q=0.5,no;q=0.4",
    "cache-control": "no-cache",
    "content-type": "application/json",
    "pragma": "no-cache",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Chromium\";v=\"140\", \"Not=A?Brand\";v=\"24\", \"Google Chrome\";v=\"140\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site"
}

# The original fetch uses POST with no body
response = requests.post(url, headers=headers)

# Check if the request was successful
if response.ok:
    # Pretty-print the JSON response
    data = response.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# {
#   "header": {
#     "OB_REQUEST_ID": "8ec32e34-fbb3-4a95-836a-1b0d2e442d68",
#     "result.val": 0,
#     "http.code": 200,
#     "result.text": "OK"
#   },
#   "data": {
#     "messages": [
#       {
#         "id": 654802,
#         "messageId": 654802,
#         "newsId": 607081,
#         "title": "Arribatec Group ASA: Mandatory notification of trade",
#         "category": [
#           {
#             "id": 1102,
#             "category_no": "MELDEPLIKTIG HANDEL FOR PRIMÆRINNSIDERE",
#             "category_en": "MANDATORY NOTIFICATION OF TRADE PRIMARY INSIDERS"
#           }
#         ],
#         "markets": [
#           "XOSL"
#         ],
#         "issuerId": 6806,
#         "correctionForMessageId": 0,
#         "correctedByMessageId": 0,
#         "issuerSign": "ARR",
#         "issuerName": "Arribatec Group ASA",
#         "instrId": 0,
#         "instrumentName": "",
#         "instrumentFullName": "",
#         "publishedTime": "2025-09-05T12:45:11.577Z",
# ...

# %%
import requests
import json

url = "https://api3.oslo.oslobors.no/v1/newsreader/message?messageId=654802"

headers = {
    "accept": "*/*",
    "accept-language": "en,en-GB;q=0.9,nb;q=0.8,en-US;q=0.7,fr-FR;q=0.6,fr;q=0.5,no;q=0.4",
    "cache-control": "no-cache",
    "content-type": "application/json",
    "pragma": "no-cache",
    "priority": "u=1, i",
    "sec-ch-ua": "\"Chromium\";v=\"140\", \"Not=A?Brand\";v=\"24\", \"Google Chrome\";v=\"140\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site"
}

response = requests.post(url, headers=headers)

if response.ok:
    data = response.json()
    print(json.dumps(data, indent=2, ensure_ascii=False))
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# {
#   "header": {
#     "OB_REQUEST_ID": "893e380a-441d-492c-87b8-0e10c3b62b9c",
#     "result.val": 0,
#     "http.code": 200,
#     "result.text": "OK"
#   },
#   "data": {
#     "message": {
#       "id": 654802,
#       "messageId": 654802,
#       "newsId": 607081,
#       "title": "Arribatec Group ASA: Mandatory notification of trade",
# ...
